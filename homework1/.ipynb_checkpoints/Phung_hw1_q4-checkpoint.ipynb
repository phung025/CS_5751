# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Part a)

# %%
input_data = DataFrame.from_csv('dow_jones_index.data', index_col=None)

# %%
input_data.iloc[1:15]
# Out:
#     quarter stock       date    open    high     low   close     volume  \
# 1         1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2         1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3         1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4         1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
# 5         1    AA  2/11/2011  $17.33  $17.48  $16.97  $17.37  114691279
# 6         1    AA  2/18/2011  $17.39  $17.68  $17.28  $17.28   80023895
# 7         1    AA  2/25/2011  $16.98  $17.15  $15.96  $16.68  132981863
# 8         1    AA   3/4/2011  $16.81  $16.94  $16.13  $16.58  109493077
# 9         1    AA  3/11/2011  $16.58  $16.75  $15.42  $16.03  114332562
# 10        1    AA  3/18/2011  $15.95  $16.33  $15.43  $16.11  130374108
# 11        1    AA  3/25/2011  $16.38  $17.24  $16.26  $17.09   95550392
# 12        1   AXP   1/7/2011  $43.30  $45.60  $43.11  $44.36   45102042
# ...

# %%
input_data.columns
# Out:
# Index(['quarter', 'stock', 'date', 'open', 'high', 'low', 'close', 'volume',
#        'percent_change_price', 'percent_change_volume_over_last_wk',
#        'previous_weeks_volume', 'next_weeks_open', 'next_weeks_close',
#        'percent_change_next_weeks_price', 'days_to_next_dividend',
#        'percent_return_next_dividend'],
#       dtype='object')

# %%
sns.pairplot(input_data.dropna())

# %% [markdown]
# From the plot above, we can see that the pair of variables "volume" and "previous_weeks_volume" exhibits a strong linear relationship, which indicates a high correlation.

# %% [markdown]
# ### Part b)

# %%
sns.heatmap(input_data.corr())

# %% [markdown]
# The plot of the correlation matrix shows that there's a high correlation between 2 features "volume" and "previous_weeks_volume" because the color indicates the correlation between these 2 variables is approximately 0.8
