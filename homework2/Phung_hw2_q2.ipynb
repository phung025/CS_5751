# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Part a)

# %%
data = pd.read_excel('AirQualityUCI.xlsx', index_col=None)

# %%
data.loc[:10]
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0  2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1  2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2  2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3  2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4  2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# 5  2004-03-10  23:00:00     1.2      1197.00        38   4.741012
# 6  2004-03-11  00:00:00     1.2      1185.00        31   3.624399
# 7  2004-03-11  01:00:00     1.0      1136.25        31   3.326677
# 8  2004-03-11  02:00:00     0.9      1094.00        24   2.339416
# 9  2004-03-11  03:00:00     0.6      1009.75        19   1.696658
# 10 2004-03-11  04:00:00  -200.0      1011.00        14   1.293620
#
#     PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1045.50    166.0       1056.25    113.0       1692.00      1267.50
# ...

# %% [markdown]
# ### Part b)

# %%
def rolling_mean(sequence):
    return np.cumsum(sequence)/np.arange(1, len(sequence)+1)

# %%
rolling_mean(np.arange(1, 100, 1))
# Out:
# array([  1. ,   1.5,   2. ,   2.5,   3. ,   3.5,   4. ,   4.5,   5. ,
#          5.5,   6. ,   6.5,   7. ,   7.5,   8. ,   8.5,   9. ,   9.5,
#         10. ,  10.5,  11. ,  11.5,  12. ,  12.5,  13. ,  13.5,  14. ,
#         14.5,  15. ,  15.5,  16. ,  16.5,  17. ,  17.5,  18. ,  18.5,
#         19. ,  19.5,  20. ,  20.5,  21. ,  21.5,  22. ,  22.5,  23. ,
#         23.5,  24. ,  24.5,  25. ,  25.5,  26. ,  26.5,  27. ,  27.5,
#         28. ,  28.5,  29. ,  29.5,  30. ,  30.5,  31. ,  31.5,  32. ,
#         32.5,  33. ,  33.5,  34. ,  34.5,  35. ,  35.5,  36. ,  36.5,
#         37. ,  37.5,  38. ,  38.5,  39. ,  39.5,  40. ,  40.5,  41. ,
#         41.5,  42. ,  42.5,  43. ,  43.5,  44. ,  44.5,  45. ,  45.5,
#         46. ,  46.5,  47. ,  47.5,  48. ,  48.5,  49. ,  49.5,  50. ])

# %% [markdown]
# ### Part c)

# %%
temp = data['T']
temp_rolling_mean = rolling_mean(temp)

# %%
plt.plot(np.arange(1, len(temp_rolling_mean)+1), temp_rolling_mean)
plt.ylabel('Average temperature')
plt.xlabel('i')
plt.show()

# %%
print(np.mean(temp))
print(temp_rolling_mean.tolist()[-1])
# Out:
# 9.77659951341454
# 9.77659951341454
